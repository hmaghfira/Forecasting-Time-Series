# %% [markdown]
# # 1. BUSINESS UNDERSTANDING

# %% [markdown]
# Perusahaan memiliki data transaksi sales dari periode 1981 - 2005. Perusahaan ingin mengetahui *prediksi sales tiga kuarter ke depan* akan berapa banyak.

# %% [markdown]
# # 2. DATA UNDERSTANDING

# %% [markdown]
# ### IMPORT LIBRARY

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import rcParams
import datetime as dt
# import seaborn as sns
rcParams['figure.figsize'] = 10,6

# %% [markdown]
# ### LOAD DATASET

# %%
data = pd.read_csv('time.csv')
# data

# rename Unnamed: 0 column
df=data.rename(columns={'Unnamed: 0':'Month'})
df.head()
# Out:
#     Month   Sales  AdBudget    GDP
# 0  Mar-81  1020.2     659.2  251.8
# 1  Jun-81   889.2     589.0  290.9
# 2  Sep-81   795.0     512.5  290.8
# 3  Dec-81  1003.9     614.1  292.4
# 4  Mar-82  1057.7     647.2  279.1

# %% [markdown]
# ### CHANGE MONTH TYPE TO DATETIME

# %%
# change Month format to m-Y
date='%b-%y'
month=dt.datetime.strptime('Mar-81', date)
month.strftime('%m-%y')
# Out:
# '03-81'

# %%
# convert string date to datetime
df['Month']=df['Month'].apply(lambda x: dt.datetime.strptime(x, date))
df.head()
# Out:
#        Month   Sales  AdBudget    GDP
# 0 1981-03-01  1020.2     659.2  251.8
# 1 1981-06-01   889.2     589.0  290.9
# 2 1981-09-01   795.0     512.5  290.8
# 3 1981-12-01  1003.9     614.1  292.4
# 4 1982-03-01  1057.7     647.2  279.1

# %% [markdown]
# ### SET MONTH TO INDEX

# %%
# set month to index (time series needs index to be analyzed)
df=df.set_index(['Month'])
df.head()
# Out:
#              Sales  AdBudget    GDP
# Month
# 1981-03-01  1020.2     659.2  251.8
# 1981-06-01   889.2     589.0  290.9
# 1981-09-01   795.0     512.5  290.8
# 1981-12-01  1003.9     614.1  292.4
# 1982-03-01  1057.7     647.2  279.1

# %% [markdown]
# ### DATA SET INFO

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 100 entries, 1981-03-01 to 2005-12-01
# Data columns (total 3 columns):
# Sales       100 non-null float64
# AdBudget    100 non-null float64
# GDP         100 non-null float64
# dtypes: float64(3)
# memory usage: 3.1 KB

# %% [markdown]
# Terdapat 100 record dari tahun 1981 sampai 2005. Memiliki 3 feature/field yaitu Sales, AdBudget, dan GDP. Dari ketiga feature tersebut, akan dipilih feature Sales untuk dijadikan parameter pada algoritma prediksi selanjutnya.

# %% [markdown]
# # 3. DATA EXPLORATION & PREPARATION

# %% [markdown]
# ### MISSING VALUES

# %%
#count how many missing values
count_missing = df.isnull().sum().sort_values(ascending = False)
count_missing.head(10)
# Out:
# GDP         0
# AdBudget    0
# Sales       0
# dtype: int64

# %% [markdown]
# ### CHOOSE THE USED COLUMNS

# %%
# choose Sales to be predicted by time series analysys algorithm
fin=df[['Sales']]
fin.tail()
# Out:
#              Sales
# Month
# 2004-12-01  1018.7
# 2005-03-01  1112.5
# 2005-06-01   997.4
# 2005-09-01   826.8
# 2005-12-01   992.6

# %% [markdown]
# ### PLOT TO SEE THE STATIONARY

# %%
## plot graph
plt.xlabel("Year")
plt.ylabel("Number of Sales")
plt.plot(fin)

# %% [markdown]
# Dari grafik di atas, dapat diketahui bahwa Hipotesis awal **(H0) tidak stasioner** pada ragam.

# %% [markdown]
# ### PROVING THE HIPOTHESIS

# %% [markdown]
# Whether it's already stationaire or not

# %% [markdown]
# **USING GRAPH**

# %%
# Determing rolling statistics
rolmean = fin.rolling(window=4).mean() #window 4 dipilih karena tiap tahunnya memiliki 4 records
rolstd = fin.rolling(window=4).std()
print(rolmean, rolstd)
# Out:
#                Sales
# Month
# 1981-03-01       NaN
# 1981-06-01       NaN
# 1981-09-01       NaN
# 1981-12-01   927.075
# 1982-03-01   936.450
# 1982-06-01   950.250
# 1982-09-01   946.125
# 1982-12-01   928.275
# 1983-03-01   912.975
# 1983-06-01   903.800
# 1983-09-01   892.950
# 1983-12-01   899.350
# 1984-03-01   908.750
# 1984-06-01   930.025
# 1984-09-01   944.175
# 1984-12-01   933.200
# 1985-03-01   951.300
# 1985-06-01   949.375
# 1985-09-01   957.425
# 1985-12-01   985.150
# 1986-03-01   974.700
# 1986-06-01   973.900
# 1986-09-01   975.000
# 1986-12-01   953.900
# 1987-03-01   935.500
# 1987-06-01   945.325
# 1987-09-01   937.425
# 1987-12-01   948.900
# 1988-03-01   964.675
# 1988-06-01   964.050
# ...              ...
# 1998-09-01   945.950
# 1998-12-01   930.075
# 1999-03-01   936.750
# 1999-06-01   970.925
# 1999-09-01   969.225
# 1999-12-01   989.275
# 2000-03-01   981.225
# 2000-06-01   956.075
# 2000-09-01   954.725
# 2000-12-01   919.225
# 2001-03-01   910.400
# 2001-06-01   908.125
# 2001-09-01   907.875
# 2001-12-01   920.375
# 2002-03-01   930.800
# 2002-06-01   919.200
# 2002-09-01   923.900
# 2002-12-01   944.775
# 2003-03-01   934.250
# 2003-06-01   934.100
# 2003-09-01   970.625
# 2003-12-01   984.050
# 2004-03-01  1003.250
# 2004-06-01  1026.575
# 2004-09-01  1003.900
# 2004-12-01   993.700
# 2005-03-01   999.175
# 2005-06-01   998.800
# 2005-09-01   988.850
# 2005-12-01   982.325
#
# [100 rows x 1 columns]                  Sales
# Month
# 1981-03-01         NaN
# 1981-06-01         NaN
# 1981-09-01         NaN
# 1981-12-01  105.597771
# 1982-03-01  117.603472
# 1982-06-01  113.373439
# 1982-09-01  120.951846
# 1982-12-01  114.689795
# 1983-03-01   93.859305
# 1983-06-01   91.528283
# 1983-09-01  111.685556
# 1983-12-01  115.379764
# 1984-03-01  126.890333
# 1984-06-01  133.611710
# 1984-09-01  106.291153
# 1984-12-01  106.639924
# 1985-03-01  132.486301
# 1985-06-01  131.736135
# 1985-09-01  119.284796
# 1985-12-01  118.776246
# 1986-03-01  105.655036
# 1986-06-01  105.562114
# 1986-09-01  103.480433
# 1986-12-01   98.336565
# 1987-03-01   74.751143
# 1987-06-01   84.791131
# 1987-09-01   99.521367
# 1987-12-01  102.622707
# 1988-03-01  115.334452
# 1988-06-01  114.932110
# ...                ...
# 1998-09-01  107.504837
# 1998-12-01  101.876572
# 1999-03-01  113.051861
# 1999-06-01  128.204170
# 1999-09-01  131.138638
# 1999-12-01  130.105095
# 2000-03-01  123.298375
# 2000-06-01  110.883494
# 2000-09-01  113.439980
# 2000-12-01  110.769411
# 2001-03-01   97.547834
# 2001-06-01   96.047189
# 2001-09-01   96.445818
# 2001-12-01   93.493115
# 2002-03-01  108.554226
# 2002-06-01  107.925499
# 2002-09-01  100.732550
# 2002-12-01  108.632603
# 2003-03-01   95.526105
# 2003-06-01   95.585285
# 2003-09-01   50.023886
# 2003-12-01   66.952048
# 2004-03-01   86.488940
# 2004-06-01   59.855903
# 2004-09-01   99.137178
# 2004-12-01   93.445278
# 2005-03-01  101.324540
# 2005-06-01  101.328673
# 2005-09-01  119.042919
# 2005-12-01  117.567552
#
# [100 rows x 1 columns]

# %%
# Buat ngeliat pola garis dari variansi dan mean apakah stasioner atau tidak
#Plot rolling statistics:
orig = plt.plot(fin, color='blue',label='Original')
mean = plt.plot(rolmean, color='red', label='Rolling Mean')
std = plt.plot(rolstd, color='black', label='Rolling Std')
plt.legend(loc='best')
plt.title('Rolling Mean & Standard Deviation')
plt.show(block=False)

# %% [markdown]
# Dari trendline rolling std (representasi dari **keberagaman**), terlihat bahwa line menunjukkan garis yang cenderung **belum stasioner**. Sedangkan line rolling mean (representasi dari rataan) masih belum menunjukkan garis trendline yang jelas.

# %% [markdown]
# **USING DICKEY-FULLER**

# %%
#Perform Dickey-Fuller test:
from statsmodels.tsa.stattools import adfuller
from pandas.core import datetools

print ('Results of Dickey-Fuller Test:')
dftest = adfuller(fin['Sales'], autolag='AIC')

dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
  dfoutput['Critical Value (%s)' %key] = value
  
print(dfoutput)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -3.262755
# p-value                         0.016628
# #Lags Used                      9.000000
# Number of Observations Used    90.000000
# Critical Value (1%)            -3.505190
# Critical Value (5%)            -2.894232
# Critical Value (10%)           -2.584210
# dtype: float64

# %% [markdown]
# Terlihat bahwa **p-value** menunjukkan nilai yang **kurang dari a (0,05)**, artinya menolak H0. Sehingga dapat dikatakan bahwa data **sudah stasioner terhadap ragam**.<br>
# Selanjutnya akan dilakukan log untuk membuat stasioner terhadap rataan.

# %% [markdown]
# **USING LOG** TO HANDLE MEAN

# %%
# Plot grafik
#Estimating trend using log
test_log = np.log(fin)
plt.plot(test_log)

# %%
# See the moving average
movingAverage = test_log.rolling(window=4).mean()
movingSTD = test_log.rolling(window=4).std()
plt.plot(test_log)
plt.plot(movingAverage, color='red', label='movingAverage')
plt.plot(movingSTD, color='black', label='movingSTD')
plt.legend(loc='best')
plt.show(block=False)

# %%
# Compiling differencing
dt_logMoving = test_log - movingAverage
dt_logMoving.head(12)

# Remove Nan Values
dt_logMoving.dropna(inplace=True)
dt_logMoving.head(10)
# Out:
#                Sales
# Month
# 1981-12-01  0.084631
# 1982-03-01  0.127811
# 1982-06-01 -0.000548
# 1982-09-01 -0.188486
# 1982-12-01  0.010459
# 1983-03-01  0.091740
# 1983-06-01  0.008314
# 1983-09-01 -0.188253
# 1983-12-01  0.069922
# 1984-03-01  0.136997

# %%
# Melihat hasil yang udah di log
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
  
  #Determing rolling statistics
  movingAverage = timeseries.rolling(window=4).mean()
  movingSTD = timeseries.rolling(window=4).std()
  
  #Plot rolling statistics:
  orig = plt.plot(timeseries, color='blue',label='Original')
  mean = plt.plot(movingAverage, color='red', label='Rolling Mean')
  std = plt.plot(movingSTD, color='black', label='Rolling Std')
  plt.legend(loc='best')
  plt.title('Rolling Mean & Standard Deviation')
  plt.show(block=False)
  
  #Perform Dickey-Fuller test:
  print('Result of Dickey-Fuller Test:')
  dftest = adfuller(timeseries['Sales'], autolag='AIC')
  dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lag Used','Number of Observations Used'])
  for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
  print(dfoutput)

# %%
test_stationarity(dt_logMoving)
# Out:
# Result of Dickey-Fuller Test:
# Test Statistic                 -4.747865
# p-value                         0.000068
# #Lag Used                       9.000000
# Number of Observations Used    87.000000
# Critical Value (1%)            -3.507853
# Critical Value (5%)            -2.895382
# Critical Value (10%)           -2.584824
# dtype: float64

# %%
# see the line of exponential mean
exponentialDecayWeightedAverage = test_log.ewm(halflife=12, min_periods=0, adjust=True).mean()
plt.plot(test_log)
plt.plot(exponentialDecayWeightedAverage, color='red')

# %%
dt_logMovingExp = test_log -  exponentialDecayWeightedAverage
test_stationarity(dt_logMovingExp)
# Out:
# Result of Dickey-Fuller Test:
# Test Statistic                 -3.266556
# p-value                         0.016441
# #Lag Used                       8.000000
# Number of Observations Used    91.000000
# Critical Value (1%)            -3.504343
# Critical Value (5%)            -2.893866
# Critical Value (10%)           -2.584015
# dtype: float64

# %% [markdown]
# Hasil dari log di atas terlihat bahwa garis mean dan std masih belum stasioner, oleh karena itu selanjutnya akan dilakukan differencing.

# %% [markdown]
# **USING DIFFERENCING** AFTER LOG

# %%
# Differencing after log
test_diff = test_log - test_log.shift()
plt.plot(test_diff)

# %%
# drop if there exists missing vallues
test_diff.dropna(inplace=True)
test_stationarity(test_diff)
# Out:
# Result of Dickey-Fuller Test:
# Test Statistic                 -5.098185
# p-value                         0.000014
# #Lag Used                      10.000000
# Number of Observations Used    88.000000
# Critical Value (1%)            -3.506944
# Critical Value (5%)            -2.894990
# Critical Value (10%)           -2.584615
# dtype: float64

# %% [markdown]
# Setelah dilakukan differencing, dapat dilihat bahwa nilai p-value semakin rendah di bawah nilai a (0,05). Hal ini menunjukkan bahwa data **semakin stasioner**. Selanjutnya akan dilihat karakteristik dari data.

# %% [markdown]
# ### SEE THE CHARACTERISTIC OF THE DATA

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(dt_logMovingExp)

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.subplot(411)
plt.plot(dt_logMovingExp, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal, label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()

decomposedLogData = residual
decomposedLogData.dropna(inplace=True)
test_stationarity(decomposedLogData)
# Out:
# Result of Dickey-Fuller Test:
# Test Statistic                -6.250645e+00
# p-value                        4.462846e-08
# #Lag Used                      8.000000e+00
# Number of Observations Used    8.700000e+01
# Critical Value (1%)           -3.507853e+00
# Critical Value (5%)           -2.895382e+00
# Critical Value (10%)          -2.584824e+00
# dtype: float64

# %%
# melihat nilai residual
decomposedLogData = residual
decomposedLogData.dropna(inplace=True)
test_stationarity(decomposedLogData)
# Out:
# Result of Dickey-Fuller Test:
# Test Statistic                -6.250645e+00
# p-value                        4.462846e-08
# #Lag Used                      8.000000e+00
# Number of Observations Used    8.700000e+01
# Critical Value (1%)           -3.507853e+00
# Critical Value (5%)           -2.895382e+00
# Critical Value (10%)          -2.584824e+00
# dtype: float64

# %% [markdown]
# Dari grafik di atas, dapat diketahui bahwa dataset memiliki karakteristik yang **seasonal**. Selanjutnya akan dilihat nilai PACF dan ACF untuk menentukan model yang tepat.

# %% [markdown]
# ### PACF AND ACF PLOT
# Plot ini digunakan sebagai patokan awal/leading kita untuk menentukan nilai p, d, dan q yang akan digunakan pada model (ARIMA sampai SARIMA).

# %% [markdown]
# **PLOT ACF**<br>
# Merepresentasikan nilai q atau MA

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

plot_acf(test_diff)
plt.show()

# %% [markdown]
# Plot ACF setelah dilakukan differensiasi ini menunjukkan dies down, maka hipotesis awal nilai q = 0.

# %% [markdown]
# **PLOT PACF**<br>
# Merepresentasikan nilai p atau AR

# %%
plot_pacf(test_diff)
plt.show()

# %% [markdown]
# Dari grafik di atas, dapat dilihat bahwa cut off pertama berada pada lag ke-8.

# %% [markdown]
# # 4. DATA MODELING
# Akan menggunakan algoritma AR, MA, ARMA, ARIMA, SARIMA.

# %%
# # find the best arima (less mse)

# import warnings
# from statsmodels.tsa.arima_model import ARIMA
# from sklearn.metrics import mean_squared_error
# from math import sqrt

# # evaluate an ARIMA model for a given order (p,d,q) and return RMSE
# def evaluate_arima_model(X, arima_order):
# # prepare training dataset
#     X = X.astype('float32')
#     train_size = int(len(X) * 0.50)
#     train, test = X[0:train_size], X[train_size:]
#     history = [x for x in train]
#     # make predictions
#     predictions = list()
#     for t in range(len(test)):
#         model = ARIMA(history, order=arima_order)
#         model_fit = model.fit(disp=0)
#         yhat = model_fit.forecast()[0]
#         predictions.append(yhat)
#         history.append(test[t])
#     # calculate out of sample error
#     mse = mean_squared_error(test, predictions)
#     rmse = sqrt(mse)
#     return rmse

# # evaluate combinations of p, d and q values for an ARIMA model
# def evaluate_models(dataset, p_values, d_values, q_values):
#     dataset = dataset.astype('float32')
#     best_score, best_cfg = float("inf"), None
#     for p in p_values:
#         for d in d_values:
#             for q in q_values:
#                 order = (p,d,q)
#                 try:
#                     mse = evaluate_arima_model(dataset, order)
#                     if mse < best_score:
#                         best_score, best_cfg = mse, order
#                     print('ARIMA%s MSE=%.3f' % (order,mse))
#                 except:
#                     continue
#     print('Best ARIMA%s MSE=%.3f' % (best_cfg, best_score))

# # load dataset
# # series = pd.read_csv('time.csv')
# # evaluate parameters
# p_values = range(0,3)
# d_values = range(0,3)
# q_values = range(0,3)
# warnings.filterwarnings("ignore")
# evaluate_models(indexedDataset_logScale.values, p_values, d_values, q_values)

# %% [markdown]
# ### ARIMA MODEL

# %% [markdown]
# ##### FIND BEST AR ORDER

# %%
import warnings
from statsmodels.tsa.arima_model import ARIMA

#AR MODEL (2,1,2)
model = ARIMA(test_log, order=(2,1,2))
results_AR = model.fit(disp=-1)
plt.plot(test_diff)
plt.plot(results_AR.fittedvalues, color='red')
plt.title('RSS: %.4f'% sum((results_AR.fittedvalues-test_diff["Sales"])**2))
print('Plotting AR model')
print(results_AR.summary())
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\kalmanf\kalmanfilter.py:646: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\kalmanf\kalmanfilter.py:650: FutureWarning: Conversion of the second argument of issubdtype from `complex` to `np.complexfloating` is deprecated. In future, it will be treated as `np.complex128 == np.dtype(complex).type`.
#   elif issubdtype(paramsdtype, complex):
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\kalmanf\kalmanfilter.py:577: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# Plotting AR model
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.Sales   No. Observations:                   99
# Model:                 ARIMA(2, 1, 2)   Log Likelihood                 116.836
# Method:                       css-mle   S.D. of innovations              0.073
# Date:                Fri, 06 Sep 2019   AIC                           -221.672
# Time:                        06:10:57   BIC                           -206.101
# Sample:                    06-01-1981   HQIC                          -215.372
#                          - 12-01-2005
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0006      0.002      0.276      0.783      -0.004       0.005
# ar.L1.D.Sales     0.0200      0.059      0.340      0.734      -0.095       0.135
# ar.L2.D.Sales    -0.8550      0.064    -13.413      0.000      -0.980      -0.730
# ma.L1.D.Sales    -0.8337      0.124     -6.746      0.000      -1.076      -0.591
# ma.L2.D.Sales     0.4002      0.116      3.450      0.001       0.173       0.628
#                                     Roots
# =============================================================================
#                  Real           Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            0.0117           -1.0814j            1.0814           -0.2483
# AR.2            0.0117           +1.0814j            1.0814            0.2483
# MA.1            1.0417           -1.1890j            1.5808           -0.1355
# MA.2            1.0417           +1.1890j            1.5808            0.1355
# -----------------------------------------------------------------------------

# %% [markdown]
# Terlihat bahwa nilai P>|z| untuk AR 2 dan MA 1 adalah 0, maka selanjutnya akan dilakukan modeling dengan nilai AR = 2 dan MA = 1.

# %% [markdown]
# ##### FIND BEST MA ORDER

# %%
#MA MODEL (2,1,1)
model = ARIMA(test_log, order=(2,1,1))
results_MA = model.fit(disp=-1)
plt.plot(test_diff)
plt.plot(results_MA.fittedvalues, color='red')
plt.title('RSS: %.4f'% sum((results_MA.fittedvalues-test_diff["Sales"])**2))
print('Plotting MA model')
print(results_MA.summary())
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\kalmanf\kalmanfilter.py:646: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\kalmanf\kalmanfilter.py:650: FutureWarning: Conversion of the second argument of issubdtype from `complex` to `np.complexfloating` is deprecated. In future, it will be treated as `np.complex128 == np.dtype(complex).type`.
#   elif issubdtype(paramsdtype, complex):
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\kalmanf\kalmanfilter.py:577: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# Plotting MA model
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.Sales   No. Observations:                   99
# Model:                 ARIMA(2, 1, 1)   Log Likelihood                 112.712
# Method:                       css-mle   S.D. of innovations              0.076
# Date:                Fri, 06 Sep 2019   AIC                           -215.423
# Time:                        06:12:04   BIC                           -202.448
# Sample:                    06-01-1981   HQIC                          -210.174
#                          - 12-01-2005
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0006      0.001      1.017      0.312      -0.001       0.002
# ar.L1.D.Sales    -0.0496      0.074     -0.670      0.504      -0.195       0.095
# ar.L2.D.Sales    -0.7304      0.073    -10.000      0.000      -0.874      -0.587
# ma.L1.D.Sales    -0.8802      0.106     -8.341      0.000      -1.087      -0.673
#                                     Roots
# =============================================================================
#                  Real           Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.0340           -1.1696j            1.1701           -0.2546
# AR.2           -0.0340           +1.1696j            1.1701            0.2546
# MA.1            1.1361           +0.0000j            1.1361            0.0000
# -----------------------------------------------------------------------------

# %% [markdown]
# Pada tabel terlihat bahwa nilai P>|z| untuk AR = 2 adalah 0 dan MA = 1 adalah 0, selain itu nilai AIC (merepresentasi seberapa fit model terhadap data) semakin menurun dari AR Model sebelumnya. Oleh karena itu, order untuk model **ARIMA** yang akan dipakai adalah **(2,1,1)**.

# %%
# just for validation
predictions_ARIMA_diff = pd.Series(results_MA.fittedvalues, copy=True)
print(predictions_ARIMA_diff.head())
# Out:
# Month
# 1981-06-01    0.000602
# 1981-09-01    0.022493
# 1981-12-01    0.138014
# 1982-03-01    0.017922
# 1982-06-01   -0.195458
# dtype: float64

# %%
#Convert to cumulative sum
predictions_ARIMA_diff_cumsum = predictions_ARIMA_diff.cumsum()
print(predictions_ARIMA_diff_cumsum.head())
# Out:
# Month
# 1981-06-01    0.000602
# 1981-09-01    0.023095
# 1981-12-01    0.161109
# 1982-03-01    0.179031
# 1982-06-01   -0.016427
# dtype: float64

# %% [markdown]
# ##### CALCULATE PREDICTION LOG RESULT

# %%
# Predict using test_log
predictions_ARIMA_log = pd.Series(test_log['Sales'].ix[0], index=test_log.index)
predictions_ARIMA_log = predictions_ARIMA_log.add(predictions_ARIMA_diff_cumsum,fill_value=0)
predictions_ARIMA_log.head()
# Out:
# Month
# 1981-03-01    6.927754
# 1981-06-01    6.928356
# 1981-09-01    6.950849
# 1981-12-01    7.088863
# 1982-03-01    7.106785
# dtype: float64

# %%
# # Predict using test_diff
# predictions_ARIMA_log = pd.Series(test_diff['Sales'].ix[0], index=test_diff.index)
# predictions_ARIMA_log = predictions_ARIMA_log.add(predictions_ARIMA_diff_cumsum,fill_value=0)
# predictions_ARIMA_log.head()

# %%
predictions_ARIMA = np.exp(predictions_ARIMA_log)
plt.plot(fin, label='Actual')
plt.plot(predictions_ARIMA, label='Forecast')
plt.legend()

# %% [markdown]
# ##### SEE RESIDUAL ERROR

# %%
# Plot residual errors
residuals = pd.DataFrame(results_MA.resid)
fig, ax = plt.subplots(1,2)
residuals.plot(title="Residuals", ax=ax[0])
residuals.plot(kind='kde', title='Density', ax=ax[1])
plt.show()

# %% [markdown]
# The residual errors seem fine with near zero mean and uniform variance. Let’s plot the actuals against the fitted values using plot_predict().

# %%
# Actual vs Fitted/Forecast
results_MA.plot_predict(dynamic=False)
# results_MA.plot_predict(1,264)
x=results_MA.forecast(steps=120)
print("Actual vs Forecast")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\kalmanf\kalmanfilter.py:577: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# Actual vs Forecast

# %% [markdown]
# Terlihat bahwa pola garis forecast(oren) mengikuti garis aktual(biru).

# %%
len(x[1])
# Out:
# 120

# %%
len(np.exp(x[1]))
# Out:
# 120

# %% [markdown]
# # 4. HASIL

# %% [markdown]
# ##### DEPLOYMENT

# %%
num=len(fin)

TrainingSize = int(num * 0.75)
train = fin[0:TrainingSize]
test = fin[TrainingSize:num]

# %%
# # Build Model
# # model = ARIMA(train, order=(2,1,1))  
# # model = ARIMA(train, order=(2, 1, 1))  
# # fitted = model.fit(disp=-1)  

# #new arrays to store actual and predictions
# actual = [x for x in train]
# predictions = list()

# #in a for loop, predict values using ARIMA model
# for timepoint in range(len(test)):
#     actualValue =  test[timepoint]
    
#     #forcast value    
#     model = ARIMA(train, order=(2, 1, 1))  
#     model_fits = model.fit(disp=-1)
#     res_fitted = model_fits.forecast()[0]
    
#     print('Actual=%f, Predicted=%f' % (actualValue, res_fitted))
#     #add it in the list
#     predictions.append(res_fitted)
#     actual.append(actualValue)

# #Print MSE to see how good the model is
# Error = MeanSquaredError(test, predictions)
# print('Test Mean Squared Error (smaller the better fit): %.3f' % Error)
# # plot
# pyplot.plot(test)
# pyplot.plot(predictions, color='red')
# pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-07a64619343d> in <module>()
#      10 #in a for loop, predict values using ARIMA model
#      11 for timepoint in range(len(test)):
# ---> 12     actualValue =  test[timepoint]
#      13
#      14     #forcast value
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0

# %% [markdown]
# ##### save result to Series

# %%
predictions_diff = pd.Series(results_MA.fittedvalues, copy=True)
print(len(predictions_ARIMA_diff))
a=pd.DataFrame()
a['Real']=test_log['Sales']
a['Pred']=predictions_ARIMA_diff.fillna(0)
a['Real pred']=a['Pred']+a['Real']
a.iloc[0,2]=6.927754
a
# Out:
# 99
#                 Real      Pred  Real pred
# Month
# 1981-03-01  6.927754       NaN   6.927754
# 1981-06-01  6.790322  0.000602   6.790925
# 1981-09-01  6.678342  0.022493   6.700835
# 1981-12-01  6.911648  0.138014   7.049662
# 1982-03-01  6.963852  0.017922   6.981774
# 1982-06-01  6.850550 -0.195458   6.655092
# 1982-09-01  6.657369 -0.093225   6.564144
# 1982-12-01  6.837869  0.172474   7.010343
# 1983-03-01  6.904249  0.126662   7.030911
# 1983-06-01  6.810914 -0.083825   6.727089
# 1983-09-01  6.600007 -0.034742   6.565265
# 1983-12-01  6.864952  0.230137   7.095089
# 1984-03-01  6.941287  0.112025   7.053311
# 1984-06-01  6.900529 -0.165349   6.735180
# 1984-09-01  6.674183 -0.160883   6.513300
# 1984-12-01  6.818049  0.099109   6.917158
# 1985-03-01  7.008957  0.120162   7.129119
# 1985-06-01  6.892743 -0.175373   6.717370
# 1985-09-01  6.714049 -0.184430   6.529619
# 1985-12-01  6.932545  0.089785   7.022330
# 1986-03-01  6.970448  0.007765   6.978213
# 1986-06-01  6.889489 -0.186863   6.702626
# 1986-09-01  6.719375 -0.115661   6.603715
# 1986-12-01  6.846624  0.116510   6.963135
# 1987-03-01  6.898815  0.109564   7.008379
# 1987-06-01  6.928734 -0.043994   6.884740
# 1987-09-01  6.680478 -0.103551   6.576927
# 1987-12-01  6.894265  0.118848   7.013113
# 1988-03-01  6.960537  0.088250   7.048787
# 1988-06-01  6.926283 -0.139020   6.787263
# ...              ...       ...        ...
# 1998-09-01  6.691587 -0.041185   6.650403
# 1998-12-01  6.839583  0.189503   7.029086
# 1999-03-01  6.986289  0.131682   7.117971
# 1999-06-01  6.968192 -0.127522   6.840670
# 1999-09-01  6.683111 -0.201497   6.481614
# 1999-12-01  6.921954  0.102003   7.023957
# 2000-03-01  6.956069  0.076991   7.033060
# 2000-06-01  6.868703 -0.137325   6.731378
# 2000-09-01  6.676328 -0.063485   6.612843
# 2000-12-01  6.771133  0.187876   6.959010
# 2001-03-01  6.921855  0.218797   7.140652
# 2001-06-01  6.859195 -0.015727   6.843468
# 2001-09-01  6.675066 -0.064591   6.610475
# 2001-12-01  6.826871  0.161190   6.988060
# 2002-03-01  6.962149  0.136286   7.098435
# 2002-06-01  6.809260 -0.115625   6.693635
# 2002-09-01  6.698515 -0.057347   6.641168
# 2002-12-01  6.913539  0.165234   7.078772
# 2003-03-01  6.921461  0.027465   6.948926
# 2003-06-01  6.808598 -0.139166   6.669431
# 2003-09-01  6.864117 -0.022268   6.841849
# 2003-12-01  6.965552  0.012281   6.977833
# 2004-03-01  6.994483 -0.122985   6.871499
# 2004-06-01  6.906655 -0.208167   6.698487
# 2004-09-01  6.764578 -0.121626   6.642952
# 2004-12-01  6.926283  0.090269   7.016552
# 2005-03-01  7.014365  0.033941   7.048306
# 2005-06-01  6.905152 -0.169058   6.736094
# 2005-09-01  6.717563 -0.110520   6.607043
# 2005-12-01  6.900328  0.157981   7.058309
#
# [100 rows x 3 columns]

# %%
res=np.exp(a)
res
# Out:
#               Real      Pred    Real pred
# Month
# 1981-03-01  1020.2       NaN  1020.200035
# 1981-06-01   889.2  1.000603   889.735779
# 1981-09-01   795.0  1.022748   813.084344
# 1981-12-01  1003.9  1.147992  1152.468742
# 1982-03-01  1057.7  1.018084  1076.827343
# 1982-06-01   944.4  0.822458   776.729284
# 1982-09-01   778.5  0.910989   709.204756
# 1982-12-01   932.5  1.188241  1108.034379
# 1983-03-01   996.5  1.135033  1131.060566
# 1983-06-01   907.7  0.919592   834.713768
# 1983-09-01   735.1  0.965855   709.999956
# 1983-12-01   958.1  1.258773  1206.030256
# 1984-03-01  1034.1  1.118540  1156.682591
# 1984-06-01   992.8  0.847598   841.494875
# 1984-09-01   791.7  0.851392   674.046940
# 1984-12-01   914.2  1.104186  1009.447251
# 1985-03-01  1106.5  1.127680  1247.777609
# 1985-06-01   985.1  0.839144   826.640477
# 1985-09-01   823.9  0.831578   685.137383
# 1985-12-01  1025.1  1.093939  1121.396873
# 1986-03-01  1064.7  1.007795  1072.999200
# 1986-06-01   981.9  0.829557   814.542047
# 1986-09-01   828.3  0.890777   737.830890
# 1986-12-01   940.7  1.123569  1056.941601
# 1987-03-01   991.1  1.115791  1105.860784
# 1987-06-01  1021.2  0.956960   977.247342
# 1987-09-01   796.7  0.901630   718.328533
# 1987-12-01   986.6  1.126199  1111.107909
# 1988-03-01  1054.2  1.092261  1151.461391
# 1988-06-01  1018.7  0.870211   886.483709
# ...            ...       ...          ...
# 1998-09-01   805.6  0.959652   773.095458
# 1998-12-01   934.1  1.208649  1128.998627
# 1999-03-01  1081.7  1.140745  1233.943830
# 1999-06-01  1062.3  0.880274   935.115234
# 1999-09-01   798.8  0.817506   653.023807
# 1999-12-01  1014.3  1.107387  1123.222952
# 2000-03-01  1049.5  1.080032  1133.493989
# 2000-06-01   961.7  0.871687   838.301573
# 2000-09-01   793.4  0.938488   744.596753
# 2000-12-01   872.3  1.206684  1052.590789
# 2001-03-01  1014.2  1.244579  1262.251663
# 2001-06-01   952.6  0.984396   937.735519
# 2001-09-01   792.4  0.937450   742.835707
# 2001-12-01   922.3  1.174908  1083.617751
# 2002-03-01  1055.9  1.146010  1210.071592
# 2002-06-01   906.2  0.890809   807.251514
# 2002-09-01   811.2  0.944266   765.988910
# 2002-12-01  1005.8  1.179669  1186.510713
# 2003-03-01  1013.8  1.027846  1042.030071
# 2003-06-01   905.6  0.870083   787.947324
# 2003-09-01   957.3  0.977978   936.218296
# 2003-12-01  1059.5  1.012356  1072.591650
# 2004-03-01  1090.6  0.884277   964.392732
# 2004-06-01   998.9  0.812071   811.177913
# 2004-09-01   866.6  0.885480   767.356864
# 2004-12-01  1018.7  1.094469  1114.935561
# 2005-03-01  1112.5  1.034524  1150.907669
# 2005-06-01   997.4  0.844460   842.264273
# 2005-09-01   826.8  0.895369   740.290728
# 2005-12-01   992.6  1.171144  1162.477842
#
# [100 rows x 3 columns]

# %% [markdown]
# ##### CALCULATE THE MSE AND RMSE

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
# MSE
mse=mean_squared_error(fin['Sales'], predictions_diff)
# MAPE
mape=mean_absolute_error(fin['Sales'], predictions_diff)
# percent_mape=mape*100

print("The MSE is\t: %.2f" % mse)
print("The MAPE is\t: %.2f" % mape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-1b6d412bdb37> in <module>()
#       1 # MSE
# ----> 2 mse=mean_squared_error(fin['Sales'], predictions_diff)
#       3 # MAPE
#       4 mape=mean_absolute_error(fin['Sales'], predictions_diff)
#       5 # percent_mape=mape*100
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput)
#     236     """
#     237     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 238         y_true, y_pred, multioutput)
#     239     output_errors = np.average((y_true - y_pred) ** 2, axis=0,
#     240                                weights=sample_weight)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\regression.py in _check_reg_targets(y_true, y_pred, multioutput)
#      73
#      74     """
# ---> 75     check_consistent_length(y_true, y_pred)
#      76     y_true = check_array(y_true, ensure_2d=False)
#      77     y_pred = check_array(y_pred, ensure_2d=False)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     202     if len(uniques) > 1:
#     203         raise ValueError("Found input variables with inconsistent numbers of"
# --> 204                          " samples: %r" % [int(l) for l in lengths])
#     205
#     206
#
# ValueError: Found input variables with inconsistent numbers of samples: [100, 99]

# %% [markdown]
# # PLOT PREDICT

# %%
a['Real pred'].plot_predict(1,264)
x=a['Real pred'].forecast(steps=120)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-68-e78bbc49fce7> in <module>()
# ----> 1 a['Real pred'].plot_predict(1,264)
#       2 x=a['Real pred'].forecast(steps=120)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'plot_predict'
